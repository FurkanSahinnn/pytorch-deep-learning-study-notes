# %%
import torch

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # LSTM:
#
# <img src="images/lstm_1.png"  width="900" height="450">
#
# - **Forget Gate:** Geçmişten gelecek bilginin hangilerinin unutulup hangilerinin unutulmayacağını belirlemeyi sağlar.
# - **Input Gate:** Gelecek yeni input'un cell'e eklenip eklenmeyeceğini belirlemeyi sağlar. Burada Candidate memory ifadesi, memory'e tutulacak input'ların belirlenmesinde rol oynar.
# - **Output Gate:** Bir sonraki cell'e hangi bilgilerin aktarılacağının belirlenmesini sağlar.
#
# ### LSTM'deki İfadelerin Sayısal Gösterimleri:
#
# <img src="images/lstm_2.png"  width="900" height="450">

# %%
import torch.nn as nn
import torch.optim as optim
import re
from collections import Counter # For counting elements
from itertools import product # For generating combinations

# %%
# 1. Read the text file and clean it
def preprocess_shakespeare(text):
    # Remove stage directions and other text in square brackets (e.g., [Enter stage left])
    text = re.sub(r'\[.*?\]', '', text)
    
    # Remove "ACT" and "Scene" markers (e.g., "ACT 1", "Scene 2"), ignoring case
    text = re.sub(r'ACT\s+\d+|Scene\s+\d+', '', text, flags=re.IGNORECASE)
    
    # Remove character names, which are typically in all caps at the start of a line
    text = re.sub(r'^[A-Z][A-Z\s]+(?=\n)', '', text, flags=re.MULTILINE)
    
    # Replace multiple consecutive newlines with a single newline
    text = re.sub(r'\n+', '\n', text)
    
    # Replace multiple consecutive spaces with a single space
    text = re.sub(r'[ ]{2,}', ' ', text)
    
    # Remove any stray "=" characters from the text
    text = text.replace('=', '')
    
    # Remove full web URLs that start with http or https
    text = re.sub(r'http[s]?://\S+', '', text)
    
    # Remove web addresses that start with www.
    text = re.sub(r'www\.\S+', '', text)
    
    text = text.lower()
    return text.strip()

# %%
with open('data/a-midsummer-nights-dream_TXT_FolgerShakespeare.txt', 'r') as file:
    raw_data = file.read()

cleaned_data = preprocess_shakespeare(raw_data)

cleaned_data[:500]
# Out:
# "a midsummer night's dream\nby william shakespeare\nedited by barbara a. mowat and paul werstine\n with michael poston and rebecca niles\nfolger shakespeare library\n\ncreated on jul 31, 2015, from fdt version 0.9.2\ncharacters in the play\n\nfour lovers:\n hermia\n lysander\n helena\n demetrius\ntheseus, duke of athens\nhippolyta, queen of the amazons\negeus, father to hermia\nphilostrate, master of the revels to theseus\nnick bottom, weaver\npeter quince, carpenter\nfrancis flute, bellows-mender\ntom snout, tinker\n"

# %%
# 2. Split text into words
words = cleaned_data.split()
words
# Out:
# ['a',
#  'midsummer',
#  "night's",
#  'dream',
#  'by',
#  'william',
#  'shakespeare',
#  'edited',
#  'by',
#  'barbara',
#  'a.',
#  'mowat',
#  'and',
#  'paul',
#  'werstine',
#  'with',
#  'michael',
#  'poston',
#  'and',
#  'rebecca',
#  'niles',
#  'folger',
#  'shakespeare',
#  'library',
#  'created',
#  'on',
#  'jul',
#  '31,',
#  '2015,',
#  'from',
#  'fdt',
#  'version',
#  '0.9.2',
#  'characters',
#  'in',
#  'the',
#  'play',
#  'four',
#  'lovers:',
#  'hermia',
#  'lysander',
#  'helena',
#  'demetrius',
#  'theseus,',
#  'duke',
#  'of',
#  'athens',
#  'hippolyta,',
#  'queen',
#  'of',
#  'the',
#  'amazons',
#  'egeus,',
#  'father',
#  'to',
#  'hermia',
#  'philostrate,',
#  'master',
#  'of',
#  'the',
#  'revels',
#  'to',
#  'theseus',
#  'nick',
#  'bottom,',
#  'weaver',
#  'peter',
#  'quince,',
#  'carpenter',
#  'francis',
#  'flute,',
#  'bellows-mender',
#  'tom',
#  'snout,',
#  'tinker',
#  'snug,',
#  'joiner',
#  'robin',
#  'starveling,',
#  'tailor',
#  'oberon,',
#  'king',
#  'of',
#  'the',
#  'fairies',
#  'titania,',
#  'queen',
#  'of',
#  'the',
#  'fairies',
#  'robin',
#  'goodfellow,',
#  'a',
#  '"puck,"',
#  'or',
#  'hobgoblin,',
#  'in',
#  "oberon's",
#  'service',
#  'a',
#  'fairy,',
#  'in',
#  'the',
#  'service',
#  'of',
#  'titania',
#  'fairies',
#  'attending',
#  'upon',
#  'titania:',
#  'peaseblossom',
#  'cobweb',
#  'mote',
#  'mustardseed',
#  'lords',
#  'and',
#  'attendants',
#  'on',
#  'theseus',
#  'and',
#  'hippolyta',
#  'other',
#  'fairies',
#  'in',
#  'the',
#  'trains',
#  'of',
#  'titania',
#  'and',
#  'oberon',
#  'now,',
#  'fair',
#  'hippolyta,',
#  'our',
#  'nuptial',
#  'hour',
#  'draws',
#  'on',
#  'apace.',
#  'four',
#  'happy',
#  'days',
#  'bring',
#  'in',
#  'another',
#  'moon.',
#  'but,',
#  'o,',
#  'methinks',
#  'how',
#  'slow',
#  'this',
#  'old',
#  'moon',
#  'wanes!',
#  'she',
#  'lingers',
#  'my',
#  'desires',
#  'like',
#  'to',
#  'a',
#  'stepdame',
#  'or',
#  'a',
#  'dowager',
#  'long',
#  'withering',
#  'out',
#  'a',
#  'young',
#  "man's",
#  'revenue.',
#  'four',
#  'days',
#  'will',
#  'quickly',
#  'steep',
#  'themselves',
#  'in',
#  'night;',
#  'four',
#  'nights',
#  'will',
#  'quickly',
#  'dream',
#  'away',
#  'the',
#  'time;',
#  'and',
#  'then',
#  'the',
#  'moon,',
#  'like',
#  'to',
#  'a',
#  'silver',
#  'bow',
#  'new-bent',
#  'in',
#  'heaven,',
#  'shall',
#  'behold',
#  'the',
#  'night',
#  'of',
#  'our',
#  'solemnities.',
#  'theseus',
#  'go,',
#  'philostrate,',
#  'stir',
#  'up',
#  'the',
#  'athenian',
#  'youth',
#  'to',
#  'merriments.',
#  'awake',
#  'the',
#  'pert',
#  'and',
#  'nimble',
#  'spirit',
#  'of',
#  'mirth.',
#  'turn',
#  'melancholy',
#  'forth',
#  'to',
#  'funerals;',
#  'the',
#  'pale',
#  'companion',
#  'is',
#  'not',
#  'for',
#  'our',
#  'pomp.',
#  'hippolyta,',
#  'i',
#  'wooed',
#  'thee',
#  'with',
#  'my',
#  'sword',
#  'and',
#  'won',
#  'thy',
#  'love',
#  'doing',
#  'thee',
#  'injuries,',
#  'but',
#  'i',
#  'will',
#  'wed',
#  'thee',
#  'in',
#  'another',
#  'key,',
#  'with',
#  'pomp,',
#  'with',
#  'triumph,',
#  'and',
#  'with',
#  'reveling.',
#  '[enter',
#  'egeus',
#  'and',
#  'his',
#  'daughter',
#  'hermia,',
#  'and',
#  'lysander',
#  'and',
#  'demetrius.]',
#  'happy',
#  'be',
#  'theseus,',
#  'our',
#  'renowned',
#  'duke!',
#  'thanks,',
#  'good',
#  'egeus.',
#  "what's",
#  'the',
#  'news',
#  'with',
#  'thee?',
#  'full',
#  'of',
#  'vexation',
#  'come',
#  'i,',
#  'with',
#  'complaint',
#  'against',
#  'my',
#  'child,',
#  'my',
#  'daughter',
#  'hermia.--',
#  'stand',
#  'forth,',
#  'demetrius.--my',
#  'noble',
#  'lord,',
#  'this',
#  'man',
#  'hath',
#  'my',
#  'consent',
#  'to',
#  'marry',
#  'her.--',
#  'stand',
#  'forth,',
#  'lysander.--and,',
#  'my',
#  'gracious',
#  'duke,',
#  'this',
#  'man',
#  'hath',
#  'bewitched',
#  'the',
#  'bosom',
#  'of',
#  'my',
#  'child.--',
#  'thou,',
#  'thou,',
#  'lysander,',
#  'thou',
#  'hast',
#  'given',
#  'her',
#  'rhymes',
#  'and',
#  'interchanged',
#  'love',
#  'tokens',
#  'with',
#  'my',
#  'child.',
#  'thou',
#  'hast',
#  'by',
#  'moonlight',
#  'at',
#  'her',
#  'window',
#  'sung',
#  'with',
#  'feigning',
#  'voice',
#  'verses',
#  'of',
#  'feigning',
#  'love',
#  'and',
#  "stol'n",
#  'the',
#  'impression',
#  'of',
#  'her',
#  'fantasy',
#  'with',
#  'bracelets',
#  'of',
#  'thy',
#  'hair,',
#  'rings,',
#  'gauds,',
#  'conceits,',
#  'knacks,',
#  'trifles,',
#  'nosegays,',
#  'sweetmeats--messengers',
#  'of',
#  'strong',
#  'prevailment',
#  'in',
#  'unhardened',
#  'youth.',
#  'with',
#  'cunning',
#  'hast',
#  'thou',
#  'filched',
#  'my',
#  "daughter's",
#  'heart,',
#  'turned',
#  'her',
#  'obedience',
#  '(which',
#  'is',
#  'due',
#  'to',
#  'me)',
#  'to',
#  'stubborn',
#  'harshness.--and,',
#  'my',
#  'gracious',
#  'duke,',
#  'be',
#  'it',
#  'so',
#  'she',
#  'will',
#  'not',
#  'here',
#  'before',
#  'your',
#  'grace',
#  'consent',
#  'to',
#  'marry',
#  'with',
#  'demetrius,',
#  'i',
#  'beg',
#  'the',
#  'ancient',
#  'privilege',
#  'of',
#  'athens:',
#  'as',
#  'she',
#  'is',
#  'mine,',
#  'i',
#  'may',
#  'dispose',
#  'of',
#  'her,',
#  'which',
#  'shall',
#  'be',
#  'either',
#  'to',
#  'this',
#  'gentleman',
#  'or',
#  'to',
#  'her',
#  'death,',
#  'according',
#  'to',
#  'our',
#  'law',
#  'immediately',
#  'provided',
#  'in',
#  'that',
#  'case.',
#  'what',
#  'say',
#  'you,',
#  'hermia?',
#  'be',
#  'advised,',
#  'fair',
#  'maid.',
#  'to',
#  'you,',
#  'your',
#  'father',
#  'should',
#  'be',
#  'as',
#  'a',
#  'god,',
#  'one',
#  'that',
#  'composed',
#  'your',
#  'beauties,',
#  'yea,',
#  'and',
#  'one',
#  'to',
#  'whom',
#  'you',
#  'are',
#  'but',
#  'as',
#  'a',
#  'form',
#  'in',
#  'wax',
#  'by',
#  'him',
#  'imprinted,',
#  'and',
#  'within',
#  'his',
#  'power',
#  'to',
#  'leave',
#  'the',
#  'figure',
#  'or',
#  'disfigure',
#  'it.',
#  'demetrius',
#  'is',
#  'a',
#  'worthy',
#  'gentleman.',
#  'so',
#  'is',
#  'lysander.',
#  'theseus',
#  'in',
#  'himself',
#  'he',
#  'is,',
#  'but',
#  'in',
#  'this',
#  'kind,',
#  'wanting',
#  'your',
#  "father's",
#  'voice,',
#  'the',
#  'other',
#  'must',
#  'be',
#  'held',
#  'the',
#  'worthier.',
#  'i',
#  'would',
#  'my',
#  'father',
#  'looked',
#  'but',
#  'with',
#  'my',
#  'eyes.',
#  'rather',
#  'your',
#  'eyes',
#  'must',
#  'with',
#  'his',
#  'judgment',
#  'look.',
#  'i',
#  'do',
#  'entreat',
#  'your',
#  'grace',
#  'to',
#  'pardon',
#  'me.',
#  'i',
#  'know',
#  'not',
#  'by',
#  'what',
#  'power',
#  'i',
#  'am',
#  'made',
#  'bold,',
#  'nor',
#  'how',
#  'it',
#  'may',
#  'concern',
#  'my',
#  'modesty',
#  'in',
#  'such',
#  'a',
#  'presence',
#  'here',
#  'to',
#  'plead',
#  'my',
#  'thoughts;',
#  'but',
#  'i',
#  'beseech',
#  'your',
#  'grace',
#  'that',
#  'i',
#  'may',
#  'know',
#  'the',
#  'worst',
#  'that',
#  'may',
#  'befall',
#  'me',
#  'in',
#  'this',
#  'case',
#  'if',
#  'i',
#  'refuse',
#  'to',
#  'wed',
#  'demetrius.',
#  'either',
#  'to',
#  'die',
#  'the',
#  'death',
#  'or',
#  'to',
#  'abjure',
#  'forever',
#  'the',
#  'society',
#  'of',
#  'men.',
#  'therefore,',
#  'fair',
#  'hermia,',
#  'question',
#  'your',
#  'desires,',
#  'know',
#  'of',
#  'your',
#  'youth,',
#  'examine',
#  'well',
#  'your',
#  'blood,',
#  'whether',
#  '(if',
#  'you',
#  'yield',
#  'not',
#  'to',
#  'your',
#  "father's",
#  'choice)',
#  'you',
#  'can',
#  'endure',
#  'the',
#  'livery',
#  'of',
#  'a',
#  'nun,',
#  'for',
#  'aye',
#  'to',
#  'be',
#  'in',
#  'shady',
#  'cloister',
#  'mewed,',
#  'to',
#  'live',
#  'a',
#  'barren',
#  'sister',
#  'all',
#  'your',
#  'life,',
#  'chanting',
#  'faint',
#  'hymns',
#  'to',
#  'the',
#  'cold',
#  'fruitless',
#  'moon.',
#  'thrice-blessed',
#  'they',
#  'that',
#  'master',
#  'so',
#  'their',
#  'blood',
#  'to',
#  'undergo',
#  'such',
#  'maiden',
#  'pilgrimage,',
#  'but',
#  'earthlier',
#  'happy',
#  'is',
#  'the',
#  'rose',
#  'distilled',
#  'than',
#  'that',
#  'which,',
#  'withering',
#  'on',
#  'the',
#  'virgin',
#  'thorn,',
#  'grows,',
#  'lives,',
#  'and',
#  'dies',
#  'in',
#  'single',
#  'blessedness.',
#  'so',
#  'will',
#  'i',
#  'grow,',
#  'so',
#  'live,',
#  'so',
#  'die,',
#  'my',
#  'lord,',
#  'ere',
#  'i',
#  'will',
#  'yield',
#  'my',
#  'virgin',
#  'patent',
#  'up',
#  'unto',
#  'his',
#  'lordship',
#  'whose',
#  'unwished',
#  'yoke',
#  'my',
#  'soul',
#  'consents',
#  'not',
#  'to',
#  'give',
#  'sovereignty.',
#  'take',
#  'time',
#  'to',
#  'pause,',
#  'and',
#  'by',
#  'the',
#  'next',
#  'new',
#  'moon',
#  '(the',
#  'sealing',
#  'day',
#  'betwixt',
#  'my',
#  'love',
#  'and',
#  'me',
#  'for',
#  'everlasting',
#  'bond',
#  'of',
#  'fellowship),',
#  'upon',
#  'that',
#  'day',
#  'either',
#  'prepare',
#  'to',
#  'die',
#  'for',
#  'disobedience',
#  'to',
#  'your',
#  "father's",
#  'will,',
#  'or',
#  'else',
#  'to',
#  'wed',
#  'demetrius,',
#  'as',
#  'he',
#  'would,',
#  'or',
#  'on',
#  "diana's",
#  'altar',
#  'to',
#  'protest',
#  'for',
#  'aye',
#  'austerity',
#  'and',
#  'single',
#  'life.',
#  'relent,',
#  'sweet',
#  'hermia,',
#  'and,',
#  'lysander,',
#  'yield',
#  'thy',
#  'crazed',
#  'title',
#  'to',
#  'my',
#  'certain',
#  'right.',
#  'you',
#  'have',
#  'her',
#  "father's",
#  'love,',
#  'demetrius.',
#  'let',
#  'me',
#  'have',
#  "hermia's.",
#  'do',
#  'you',
#  'marry',
#  'him.',
#  'scornful',
#  'lysander,',
#  'true,',
#  'he',
#  'hath',
#  'my',
#  'love;',
#  'and',
#  'what',
#  'is',
#  'mine',
#  'my',
#  'love',
#  'shall',
#  'render',
#  'him.',
#  'and',
#  'she',
#  'is',
#  'mine,',
#  'and',
#  'all',
#  'my',
#  'right',
#  'of',
#  'her',
#  'i',
#  'do',
#  'estate',
#  'unto',
#  'demetrius.',
#  'lysander,',
#  'i',
#  'am,',
#  'my',
#  'lord,',
#  'as',
#  'well',
#  'derived',
#  'as',
#  'he,',
#  'as',
#  'well',
#  'possessed.',
#  'my',
#  'love',
#  'is',
#  'more',
#  'than',
#  'his;',
#  'my',
#  'fortunes',
#  'every',
#  'way',
#  'as',
#  'fairly',
#  'ranked',
#  '(if',
#  'not',
#  'with',
#  'vantage)',
#  'as',
#  "demetrius';",
#  'and',
#  '(which',
#  'is',
#  'more',
#  'than',
#  'all',
#  'these',
#  'boasts',
#  'can',
#  'be)',
#  'i',
#  'am',
#  'beloved',
#  'of',
#  'beauteous',
#  'hermia.',
#  'why',
#  'should',
#  'not',
#  'i',
#  'then',
#  'prosecute',
#  'my',
#  'right?',
#  'demetrius,',
#  "i'll",
#  'avouch',
#  'it',
#  'to',
#  'his',
#  'head,',
#  'made',
#  'love',
#  'to',
#  "nedar's",
#  'daughter,',
#  'helena,',
#  'and',
#  'won',
#  'her',
#  'soul;',
#  'and',
#  'she,',
#  'sweet',
#  'lady,',
#  'dotes,',
#  'devoutly',
#  'dotes,',
#  'dotes',
#  'in',
#  'idolatry,',
#  'upon',
#  'this',
#  'spotted',
#  'and',
#  'inconstant',
#  'man.',
#  'i',
#  'must',
#  'confess',
#  'that',
#  'i',
#  'have',
#  'heard',
#  'so',
#  'much,',
#  'and',
#  'with',
#  'demetrius',
#  'thought',
#  'to',
#  'have',
#  'spoke',
#  'thereof;',
#  'but,',
#  'being',
#  'overfull',
#  'of',
#  'self-affairs,',
#  'my',
#  'mind',
#  'did',
#  'lose',
#  'it.--but,',
#  'demetrius,',
#  'come,',
#  'and',
#  'come,',
#  'egeus;',
#  'you',
#  'shall',
#  'go',
#  'with',
#  'me.',
#  'i',
#  'have',
#  'some',
#  'private',
#  'schooling',
#  'for',
#  'you',
#  'both.--',
#  'for',
#  'you,',
#  'fair',
#  'hermia,',
#  'look',
#  'you',
#  ...]

# %%
# 3. Build Vocabulary
word_counts = Counter(words)
sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)

word_to_idx = {word: i for i, word in enumerate(sorted_vocab)}
idx_to_word = {i: word for i, word in enumerate(sorted_vocab)}

vocab_size = len(word_to_idx)

# %%
word_to_idx
# Out:
# {'the': 0,
#  'and': 1,
#  'i': 2,
#  'to': 3,
#  'of': 4,
#  'a': 5,
#  'in': 6,
#  'you': 7,
#  'my': 8,
#  'is': 9,
#  'with': 10,
#  'that': 11,
#  'not': 12,
#  'this': 13,
#  'for': 14,
#  'your': 15,
#  'as': 16,
#  'it': 17,
#  'thou': 18,
#  'will': 19,
#  'but': 20,
#  'me': 21,
#  'have': 22,
#  'do': 23,
#  'his': 24,
#  'be': 25,
#  'so': 26,
#  'he': 27,
#  'her': 28,
#  'all': 29,
#  'shall': 30,
#  'we': 31,
#  'by': 32,
#  'love': 33,
#  'are': 34,
#  'thy': 35,
#  'no': 36,
#  'on': 37,
#  'or': 38,
#  'if': 39,
#  'our': 40,
#  'when': 41,
#  'she': 42,
#  'what': 43,
#  'from': 44,
#  'am': 45,
#  'their': 46,
#  'bottom': 47,
#  'now': 48,
#  'must': 49,
#  'at': 50,
#  'here': 51,
#  'more': 52,
#  'quince': 53,
#  'sweet': 54,
#  'thee': 55,
#  'good': 56,
#  'hath': 57,
#  'would': 58,
#  'o': 59,
#  'one': 60,
#  'did': 61,
#  'some': 62,
#  'how': 63,
#  'come': 64,
#  'let': 65,
#  'make': 66,
#  'should': 67,
#  'demetrius': 68,
#  'then': 69,
#  'never': 70,
#  'me,': 71,
#  'man': 72,
#  'him': 73,
#  'than': 74,
#  'an': 75,
#  'theseus': 76,
#  'you,': 77,
#  'can': 78,
#  'they': 79,
#  'see': 80,
#  'doth': 81,
#  'these': 82,
#  'may': 83,
#  'upon': 84,
#  'which': 85,
#  'there': 86,
#  'play': 87,
#  'lysander': 88,
#  'fair': 89,
#  "i'll": 90,
#  'was': 91,
#  'through': 92,
#  'like': 93,
#  'them': 94,
#  'where': 95,
#  'such': 96,
#  'night': 97,
#  'me.': 98,
#  'look': 99,
#  'up': 100,
#  'nor': 101,
#  'take': 102,
#  'and,': 103,
#  'come,': 104,
#  'o,': 105,
#  'say': 106,
#  'eyes': 107,
#  'pyramus': 108,
#  'lord,': 109,
#  'give': 110,
#  'you.': 111,
#  'yet': 112,
#  'fairy': 113,
#  'out': 114,
#  'hermia,': 115,
#  'two': 116,
#  'bottom,': 117,
#  'lysander,': 118,
#  'know': 119,
#  'were': 120,
#  'most': 121,
#  'hear': 122,
#  'thisbe': 123,
#  'lion': 124,
#  'had': 125,
#  'hast': 126,
#  'gentle': 127,
#  'speak': 128,
#  'athens': 129,
#  'leave': 130,
#  'well': 131,
#  'mine': 132,
#  'every': 133,
#  'go': 134,
#  'true': 135,
#  'things': 136,
#  'meet': 137,
#  'art': 138,
#  'tell': 139,
#  'i,': 140,
#  'why': 141,
#  'follow': 142,
#  'ever': 143,
#  'no,': 144,
#  'heart': 145,
#  'helena': 146,
#  'flute,': 147,
#  'demetrius,': 148,
#  'made': 149,
#  'ere': 150,
#  'love,': 151,
#  'cannot': 152,
#  'till': 153,
#  'therefore': 154,
#  'pyramus,': 155,
#  'now,': 156,
#  'athenian': 157,
#  'lovers': 158,
#  'us': 159,
#  'pray': 160,
#  'what,': 161,
#  'thus': 162,
#  'who': 163,
#  'titania': 164,
#  'away': 165,
#  'day': 166,
#  'could': 167,
#  'it,': 168,
#  'night,': 169,
#  'love.': 170,
#  'comes': 171,
#  'helena.': 172,
#  'then,': 173,
#  'so.': 174,
#  'flute': 175,
#  'very': 176,
#  'think': 177,
#  'eye,': 178,
#  'wall,': 179,
#  'robin,': 180,
#  'hermia': 181,
#  'robin': 182,
#  'hippolyta': 183,
#  'but,': 184,
#  'moon': 185,
#  'moon,': 186,
#  'go,': 187,
#  '[enter': 188,
#  'eyes.': 189,
#  'unto': 190,
#  'else': 191,
#  'both': 192,
#  'wood': 193,
#  'thee.': 194,
#  'best': 195,
#  'snout': 196,
#  'here,': 197,
#  'into': 198,
#  'sometime': 199,
#  'well.': 200,
#  'find': 201,
#  'sleep': 202,
#  'thee,': 203,
#  'came': 204,
#  'queen': 205,
#  'peter': 206,
#  'other': 207,
#  'long': 208,
#  'stand': 209,
#  'her,': 210,
#  'is,': 211,
#  'being': 212,
#  'desire': 213,
#  'too': 214,
#  'poor': 215,
#  'same': 216,
#  'keep': 217,
#  'call': 218,
#  'part': 219,
#  'fear': 220,
#  'much': 221,
#  'ay,': 222,
#  'sing': 223,
#  'so,': 224,
#  'though': 225,
#  'duke': 226,
#  'master': 227,
#  'titania,': 228,
#  'oberon': 229,
#  'bring': 230,
#  'moon.': 231,
#  'thou,': 232,
#  'before': 233,
#  'within': 234,
#  'power': 235,
#  'it.': 236,
#  'death': 237,
#  'whose': 238,
#  'heard': 239,
#  'run': 240,
#  'any': 241,
#  'great': 242,
#  'him,': 243,
#  'for,': 244,
#  'back': 245,
#  'lady': 246,
#  'nay,': 247,
#  'little': 248,
#  'lovely': 249,
#  'why,': 250,
#  'those': 251,
#  'here.': 252,
#  'get': 253,
#  'kill': 254,
#  'lulla,': 255,
#  'wall': 256,
#  'wall.': 257,
#  'dream': 258,
#  'starveling,': 259,
#  'oberon,': 260,
#  'happy': 261,
#  'another': 262,
#  'full': 263,
#  'either': 264,
#  "father's": 265,
#  'demetrius.': 266,
#  'die,': 267,
#  'time': 268,
#  'next': 269,
#  'him.': 270,
#  'love?': 271,
#  'because': 272,
#  'place': 273,
#  'men': 274,
#  'loves': 275,
#  'go.': 276,
#  'still': 277,
#  "o'er": 278,
#  'down': 279,
#  'man,': 280,
#  'name': 281,
#  'set': 282,
#  'break': 283,
#  "thisbe's": 284,
#  'nothing': 285,
#  'roar': 286,
#  'not.': 287,
#  'fairies,': 288,
#  'lead': 289,
#  'since': 290,
#  'day.': 291,
#  'shalt': 292,
#  'about': 293,
#  'more.': 294,
#  'near': 295,
#  'vile': 296,
#  'speak,': 297,
#  'thisbe,': 298,
#  'hate': 299,
#  'four': 300,
#  'hippolyta,': 301,
#  'fairies': 302,
#  'cobweb': 303,
#  'mustardseed': 304,
#  'old': 305,
#  'forth': 306,
#  'against': 307,
#  'noble': 308,
#  'beg': 309,
#  'hermia?': 310,
#  'rather': 311,
#  'new': 312,
#  'that,': 313,
#  'tomorrow': 314,
#  'once': 315,
#  'stay': 316,
#  'ear': 317,
#  'eye': 318,
#  'rest': 319,
#  'none': 320,
#  'sweet,': 321,
#  'seek': 322,
#  'eyes,': 323,
#  "love's": 324,
#  'again.': 325,
#  'night.': 326,
#  'masters,': 327,
#  'ready.': 328,
#  'too.': 329,
#  'well,': 330,
#  'ladies': 331,
#  'hang': 332,
#  'hold': 333,
#  'you?': 334,
#  'not,': 335,
#  'between': 336,
#  'sleeping': 337,
#  'lullaby.': 338,
#  'harm': 339,
#  'wilt': 340,
#  'reason': 341,
#  'methought': 342,
#  'out,': 343,
#  'prologue': 344,
#  'seem': 345,
#  'bless': 346,
#  'own': 347,
#  'while': 348,
#  'left': 349,
#  'sport': 350,
#  'scorn': 351,
#  'show': 352,
#  'each': 353,
#  'told': 354,
#  'monsieur,': 355,
#  'theseus,': 356,
#  'philostrate,': 357,
#  'quince,': 358,
#  'snout,': 359,
#  'king': 360,
#  'peaseblossom': 361,
#  'methinks': 362,
#  'young': 363,
#  'heart,': 364,
#  '(which': 365,
#  'grace': 366,
#  'mine,': 367,
#  'whom': 368,
#  'therefore,': 369,
#  'life,': 370,
#  'will,': 371,
#  'hermia.': 372,
#  'helena,': 373,
#  'she,': 374,
#  'me!': 375,
#  'house': 376,
#  'only': 377,
#  'without': 378,
#  'tongue': 379,
#  'helen,': 380,
#  'sight': 381,
#  'dote': 382,
#  "hermia's": 383,
#  'boy': 384,
#  'dear': 385,
#  'snug': 386,
#  'starveling': 387,
#  '"the': 388,
#  'answer': 389,
#  'pyramus.': 390,
#  'shine': 391,
#  'far': 392,
#  "lion's": 393,
#  'be,': 394,
#  'enough': 395,
#  'wood,': 396,
#  'thorough': 397,
#  'gone.': 398,
#  'makes': 399,
#  'bear': 400,
#  'dance': 401,
#  "th'": 402,
#  'fetch': 403,
#  'might': 404,
#  'bear,': 405,
#  'charm': 406,
#  'off': 407,
#  'gone,': 408,
#  'truth': 409,
#  'even': 410,
#  'use': 411,
#  'strike': 412,
#  'hands': 413,
#  'trust': 414,
#  'me?': 415,
#  'believe': 416,
#  'do.': 417,
#  'hand': 418,
#  'prove': 419,
#  'first': 420,
#  'lord.': 421,
#  'dost': 422,
#  "wak'st,": 423,
#  'lie': 424,
#  "lysander's": 425,
#  'word': 426,
#  'help': 427,
#  'enter': 428,
#  'thus,': 429,
#  'pity': 430,
#  'play,': 431,
#  'many': 432,
#  'so?': 433,
#  'light': 434,
#  'wonder': 435,
#  'dead,': 436,
#  'be.': 437,
#  'three': 438,
#  "'tis": 439,
#  "night's": 440,
#  'egeus,': 441,
#  'revels': 442,
#  'snug,': 443,
#  'mote': 444,
#  'nuptial': 445,
#  "man's": 446,
#  'themselves': 447,
#  'stir': 448,
#  'turn': 449,
#  'pale': 450,
#  'marry': 451,
#  "stol'n": 452,
#  'turned': 453,
#  'law': 454,
#  'maid.': 455,
#  'yea,': 456,
#  'lysander.': 457,
#  'himself': 458,
#  'looked': 459,
#  'presence': 460,
#  'die': 461,
#  'men.': 462,
#  'blood,': 463,
#  'yield': 464,
#  'single': 465,
#  'life.': 466,
#  'true,': 467,
#  'right': 468,
#  'head,': 469,
#  'man.': 470,
#  'thought': 471,
#  'lose': 472,
#  'something': 473,
#  'duty': 474,
#  'high': 475,
#  'brief': 476,
#  'heaven': 477,
#  'been': 478,
#  'pursue': 479,
#  'us.': 480,
#  'swear': 481,
#  "cupid's": 482,
#  'false': 483,
#  'vows': 484,
#  'appear.': 485,
#  'face.': 486,
#  'minds': 487,
#  'often': 488,
#  'wont': 489,
#  'us,': 490,
#  'know.': 491,
#  'cupid': 492,
#  'child': 493,
#  'her.': 494,
#  'mean': 495,
#  'company': 496,
#  'here?': 497,
#  'lover': 498,
#  'tears': 499,
#  "wand'ring": 500,
#  'one.': 501,
#  'small': 502,
#  'hide': 503,
#  'day,': 504,
#  'beard,': 505,
#  'hair': 506,
#  'draw': 507,
#  'rehearse': 508,
#  'cut': 509,
#  'over': 510,
#  'swifter': 511,
#  'queen,': 512,
#  'stolen': 513,
#  'train,': 514,
#  'perforce': 515,
#  'loved': 516,
#  'flowers': 517,
#  'me;': 518,
#  'sat': 519,
#  'green': 520,
#  'fresh': 521,
#  'following': 522,
#  'rich': 523,
#  'away.': 524,
#  'way.': 525,
#  'fiery': 526,
#  'put': 527,
#  'thing': 528,
#  'hence,': 529,
#  'fond': 530,
#  'tongue,': 531,
#  'near.': 532,
#  'wake': 533,
#  'dear.': 534,
#  "we'll": 535,
#  'head.': 536,
#  'further': 537,
#  'courtesy,': 538,
#  'half': 539,
#  'force': 540,
#  'blessed': 541,
#  'fear.': 542,
#  'dead': 543,
#  'says': 544,
#  'do,': 545,
#  'perceive': 546,
#  'lion.': 547,
#  'name,': 548,
#  'present': 549,
#  'played': 550,
#  'goes': 551,
#  'wit': 552,
#  'i.': 553,
#  'bid': 554,
#  'bitter': 555,
#  'sleep,': 556,
#  'yonder': 557,
#  'tender': 558,
#  'true.': 559,
#  'thine': 560,
#  'kiss': 561,
#  'part.': 562,
#  'seems': 563,
#  'grace,': 564,
#  "i'": 565,
#  'followed': 566,
#  'monsieur': 567,
#  'dream.': 568,
#  'lovers,': 569,
#  'sixpence': 570,
#  'imagination': 571,
#  'moonshine': 572,
#  'trusty': 573,
#  'father': 574,
#  'nick': 575,
#  'service': 576,
#  'draws': 577,
#  'days': 578,
#  'slow': 579,
#  'youth': 580,
#  'spirit': 581,
#  'sword': 582,
#  'wed': 583,
#  'daughter': 584,
#  'thanks,': 585,
#  "what's": 586,
#  'consent': 587,
#  'given': 588,
#  'moonlight': 589,
#  'due': 590,
#  'death,': 591,
#  'according': 592,
#  'judgment': 593,
#  'entreat': 594,
#  'modesty': 595,
#  'beseech': 596,
#  'befall': 597,
#  'whether': 598,
#  'aye': 599,
#  'live': 600,
#  'faint': 601,
#  'cold': 602,
#  'maiden': 603,
#  'rose': 604,
#  'which,': 605,
#  'virgin': 606,
#  'soul': 607,
#  'certain': 608,
#  'way': 609,
#  'yourself': 610,
#  'hippolyta.': 611,
#  'respect': 612,
#  'spite!': 613,
#  'choice': 614,
#  'sickness': 615,
#  'lay': 616,
#  'sound,': 617,
#  'dream,': 618,
#  'earth,': 619,
#  'up.': 620,
#  'teach': 621,
#  'there,': 622,
#  'steal': 623,
#  'truly': 624,
#  'look,': 625,
#  'again': 626,
#  'green,': 627,
#  'buds': 628,
#  'yours': 629,
#  'catch': 630,
#  'world': 631,
#  'myself': 632,
#  'fly': 633,
#  "wat'ry": 634,
#  'bosoms': 635,
#  'counsel': 636,
#  'farewell,': 637,
#  'deep': 638,
#  'adieu.': 639,
#  'be!': 640,
#  'looks': 641,
#  'painted': 642,
#  'said': 643,
#  'joiner,': 644,
#  'first,': 645,
#  'on,': 646,
#  'grow': 647,
#  'marry,': 648,
#  'cruel': 649,
#  'ask': 650,
#  'foolish': 651,
#  'quince.': 652,
#  'faith,': 653,
#  'will.': 654,
#  'face,': 655,
#  'thisbe.': 656,
#  'fright': 657,
#  'all.': 658,
#  'friends,': 659,
#  'needs': 660,
#  'all,': 661,
#  'brier,': 662,
#  'serve': 663,
#  'elves': 664,
#  'fell': 665,
#  'indian': 666,
#  'boy,': 667,
#  'joy.': 668,
#  'there.': 669,
#  'jest': 670,
#  'lips': 671,
#  'met': 672,
#  'proud': 673,
#  'bed': 674,
#  'company.': 675,
#  'forsooth,': 676,
#  'mistress': 677,
#  'joy': 678,
#  'didst': 679,
#  'glimmering': 680,
#  'wind,': 681,
#  'sport.': 682,
#  'lost': 683,
#  'human': 684,
#  'mortals': 685,
#  'fall': 686,
#  'change': 687,
#  'lies': 688,
#  'yellow': 689,
#  'pretty': 690,
#  'perchance': 691,
#  'after': 692,
#  "theseus'": 693,
#  'round': 694,
#  'longer': 695,
#  'stay.': 696,
#  'puck,': 697,
#  'hither.': 698,
#  'breath': 699,
#  'madly': 700,
#  'music.': 701,
#  'saw': 702,
#  'flower,': 703,
#  'purple': 704,
#  'juice': 705,
#  'eyelids': 706,
#  'earth': 707,
#  'asleep': 708,
#  'lion,': 709,
#  'spurn': 710,
#  'alone': 711,
#  'wild': 712,
#  'holds': 713,
#  'wood.': 714,
#  'fie,': 715,
#  'woo.': 716,
#  'fare': 717,
#  'flower': 718,
#  'welcome,': 719,
#  'is.': 720,
#  'quite': 721,
#  'hateful': 722,
#  'wings': 723,
#  'double': 724,
#  'queen.': 725,
#  'nigh.': 726,
#  'away!': 727,
#  'seest': 728,
#  'troth,': 729,
#  'bed,': 730,
#  'life': 731,
#  'end': 732,
#  'bed.': 733,
#  'wish': 734,
#  'found': 735,
#  'ground.': 736,
#  'stay,': 737,
#  'thus.': 738,
#  'compare': 739,
#  'sir,': 740,
#  'awake.': 741,
#  'content': 742,
#  'tedious': 743,
#  'ripe': 744,
#  'written': 745,
#  'wherefore': 746,
#  'keen': 747,
#  "'t": 748,
#  'enough,': 749,
#  'sees': 750,
#  'hated': 751,
#  'helen': 752,
#  'alack,': 753,
#  'promise': 754,
#  'shield': 755,
#  'thing.': 756,
#  'fearful': 757,
#  'fear,': 758,
#  'hither': 759,
#  'bush': 760,
#  'chink': 761,
#  'down,': 762,
#  "e'er": 763,
#  'now?': 764,
#  'truest': 765,
#  'horse,': 766,
#  "ninny's": 767,
#  'fly,': 768,
#  'thee!': 769,
#  'place,': 770,
#  'mark': 771,
#  'dares': 772,
#  'cry': 773,
#  'say,': 774,
#  'methinks,': 775,
#  'yet,': 776,
#  'truth,': 777,
#  'together': 778,
#  'honest': 779,
#  'friends.': 780,
#  'no.': 781,
#  'peaseblossom,': 782,
#  'cobweb,': 783,
#  'hail!': 784,
#  'mustardseed.': 785,
#  "lover's": 786,
#  'sort,': 787,
#  'anon': 788,
#  'comes.': 789,
#  'sweep': 790,
#  'begin': 791,
#  'ass.': 792,
#  'lysander?': 793,
#  'passion': 794,
#  'remain.': 795,
#  'oath': 796,
#  'remedy.': 797,
#  'hand,': 798,
#  'alone.': 799,
#  'please': 800,
#  'turns': 801,
#  'mock': 802,
#  'rivals': 803,
#  'idle': 804,
#  'home': 805,
#  'thank': 806,
#  'we,': 807,
#  'weak': 808,
#  'off,': 809,
#  'dead?': 810,
#  'low': 811,
#  'legs': 812,
#  'already': 813,
#  'coward,': 814,
#  'ho,': 815,
#  'see.': 816,
#  'comes,': 817,
#  'ground': 818,
#  'lover,': 819,
#  'behind': 820,
#  "where's": 821,
#  'truly,': 822,
#  'sent': 823,
#  'silence': 824,
#  'music': 825,
#  'morning': 826,
#  'hounds': 827,
#  'doubt': 828,
#  'gone': 829,
#  'coming': 830,
#  'strange': 831,
#  'lime': 832,
#  'mantle': 833,
#  'bloody': 834,
#  'blade,': 835,
#  'night!': 836,
#  'discretion,': 837,
#  'lanthorn': 838,
#  'shakespeare': 839,
#  'created': 840,
#  'francis': 841,
#  'lords': 842,
#  'hour': 843,
#  'dowager': 844,
#  'withering': 845,
#  'quickly': 846,
#  'steep': 847,
#  'night;': 848,
#  'silver': 849,
#  'bow': 850,
#  'heaven,': 851,
#  'behold': 852,
#  'awake': 853,
#  'wooed': 854,
#  'won': 855,
#  'key,': 856,
#  'egeus': 857,
#  'egeus.': 858,
#  'thee?': 859,
#  'vexation': 860,
#  'child,': 861,
#  'forth,': 862,
#  'gracious': 863,
#  'duke,': 864,
#  'bosom': 865,
#  'child.': 866,
#  'sung': 867,
#  'feigning': 868,
#  'voice': 869,
#  'hair,': 870,
#  'strong': 871,
#  'youth.': 872,
#  'cunning': 873,
#  'me)': 874,
#  'ancient': 875,
#  'privilege': 876,
#  'gentleman': 877,
#  'form': 878,
#  'figure': 879,
#  'disfigure': 880,
#  'gentleman.': 881,
#  'kind,': 882,
#  'voice,': 883,
#  'worst': 884,
#  'youth,': 885,
#  '(if': 886,
#  'barren': 887,
#  'fruitless': 888,
#  'blood': 889,
#  'thorn,': 890,
#  'grows,': 891,
#  'live,': 892,
#  'yoke': 893,
#  'bond': 894,
#  'would,': 895,
#  "hermia's.": 896,
#  'render': 897,
#  'he,': 898,
#  'beauteous': 899,
#  "nedar's": 900,
#  'dotes,': 901,
#  'spotted': 902,
#  'confess': 903,
#  'mind': 904,
#  'fit': 905,
#  'vow': 906,
#  'business': 907,
#  'yourselves.': 908,
#  'cheek': 909,
#  'chance': 910,
#  'want': 911,
#  'ay': 912,
#  'aught': 913,
#  'enthralled': 914,
#  'stood': 915,
#  "another's": 916,
#  'making': 917,
#  'swift': 918,
#  'short': 919,
#  'darkness': 920,
#  'quick': 921,
#  'stands': 922,
#  'patience': 923,
#  'tears,': 924,
#  "fancy's": 925,
#  'aunt,': 926,
#  'son.': 927,
#  'league': 928,
#  'morn': 929,
#  'arrow': 930,
#  'simplicity': 931,
#  'souls': 932,
#  'fire': 933,
#  'under': 934,
#  'sail': 935,
#  'seen,': 936,
#  'broke': 937,
#  'whither': 938,
#  'away?': 939,
#  "tongue's": 940,
#  'air': 941,
#  'tunable': 942,
#  'hawthorn': 943,
#  "demetrius'": 944,
#  'still.': 945,
#  'gives': 946,
#  'fault': 947,
#  'place.': 948,
#  'seemed': 949,
#  'hell!': 950,
#  'visage': 951,
#  'pearl': 952,
#  "lovers'": 953,
#  'beds': 954,
#  'thence': 955,
#  'stranger': 956,
#  'luck': 957,
#  'grant': 958,
#  'you!': 959,
#  'that?': 960,
#  'holding': 961,
#  'oft': 962,
#  'oaths': 963,
#  'athens,': 964,
#  'interlude': 965,
#  'duchess': 966,
#  'wedding': 967,
#  'read': 968,
#  'actors,': 969,
#  'comedy': 970,
#  'work,': 971,
#  'assure': 972,
#  'actors': 973,
#  'weaver.': 974,
#  'proceed.': 975,
#  'kills': 976,
#  'gallant': 977,
#  'move': 978,
#  'tear': 979,
#  'in,': 980,
#  'vein.': 981,
#  'beard': 982,
#  'monstrous': 983,
#  'dear!': 984,
#  'hope': 985,
#  'fitted.': 986,
#  "mother's": 987,
#  'discretion': 988,
#  'gently': 989,
#  "'twere": 990,
#  "summer's": 991,
#  'discharge': 992,
#  'orange-tawny': 993,
#  'crowns': 994,
#  'parts,': 995,
#  'request': 996,
#  'town,': 997,
#  'moonlight.': 998,
#  'enough.': 999,
#  ...}

# %%
vocab_size
# Out:
# 4352

# %%
# Convert words to indices
indexed_words = [word_to_idx[w] for w in words]

# %%
indexed_words
# Out:
# [5,
#  1427,
#  440,
#  258,
#  32,
#  1428,
#  839,
#  1429,
#  32,
#  1430,
#  1431,
#  1432,
#  1,
#  1433,
#  1434,
#  10,
#  1435,
#  1436,
#  1,
#  1437,
#  1438,
#  1439,
#  839,
#  1440,
#  840,
#  37,
#  1441,
#  1442,
#  1443,
#  44,
#  1444,
#  1445,
#  1446,
#  1447,
#  6,
#  0,
#  87,
#  300,
#  1448,
#  181,
#  88,
#  146,
#  68,
#  356,
#  226,
#  4,
#  129,
#  301,
#  205,
#  4,
#  0,
#  1449,
#  441,
#  574,
#  3,
#  181,
#  357,
#  227,
#  4,
#  0,
#  442,
#  3,
#  76,
#  575,
#  117,
#  1450,
#  206,
#  358,
#  1451,
#  841,
#  147,
#  1452,
#  1453,
#  359,
#  1454,
#  443,
#  1455,
#  182,
#  259,
#  1456,
#  260,
#  360,
#  4,
#  0,
#  302,
#  228,
#  205,
#  4,
#  0,
#  302,
#  182,
#  1457,
#  5,
#  1458,
#  38,
#  1459,
#  6,
#  1460,
#  576,
#  5,
#  1461,
#  6,
#  0,
#  576,
#  4,
#  164,
#  302,
#  1462,
#  84,
#  1463,
#  361,
#  303,
#  444,
#  304,
#  842,
#  1,
#  1464,
#  37,
#  76,
#  1,
#  183,
#  207,
#  302,
#  6,
#  0,
#  1465,
#  4,
#  164,
#  1,
#  229,
#  156,
#  89,
#  301,
#  40,
#  445,
#  843,
#  577,
#  37,
#  1466,
#  300,
#  261,
#  578,
#  230,
#  6,
#  262,
#  231,
#  184,
#  105,
#  362,
#  63,
#  579,
#  13,
#  305,
#  185,
#  1467,
#  42,
#  1468,
#  8,
#  1469,
#  93,
#  3,
#  5,
#  1470,
#  38,
#  5,
#  844,
#  208,
#  845,
#  114,
#  5,
#  363,
#  446,
#  1471,
#  300,
#  578,
#  19,
#  846,
#  847,
#  447,
#  6,
#  848,
#  300,
#  1472,
#  19,
#  846,
#  258,
#  165,
#  0,
#  1473,
#  1,
#  69,
#  0,
#  186,
#  93,
#  3,
#  5,
#  849,
#  850,
#  1474,
#  6,
#  851,
#  30,
#  852,
#  0,
#  97,
#  4,
#  40,
#  1475,
#  76,
#  187,
#  357,
#  448,
#  100,
#  0,
#  157,
#  580,
#  3,
#  1476,
#  853,
#  0,
#  1477,
#  1,
#  1478,
#  581,
#  4,
#  1479,
#  449,
#  1480,
#  306,
#  3,
#  1481,
#  0,
#  450,
#  1482,
#  9,
#  12,
#  14,
#  40,
#  1483,
#  301,
#  2,
#  854,
#  55,
#  10,
#  8,
#  582,
#  1,
#  855,
#  35,
#  33,
#  1484,
#  55,
#  1485,
#  20,
#  2,
#  19,
#  583,
#  55,
#  6,
#  262,
#  856,
#  10,
#  1486,
#  10,
#  1487,
#  1,
#  10,
#  1488,
#  188,
#  857,
#  1,
#  24,
#  584,
#  115,
#  1,
#  88,
#  1,
#  1489,
#  261,
#  25,
#  356,
#  40,
#  1490,
#  1491,
#  585,
#  56,
#  858,
#  586,
#  0,
#  1492,
#  10,
#  859,
#  263,
#  4,
#  860,
#  64,
#  140,
#  10,
#  1493,
#  307,
#  8,
#  861,
#  8,
#  584,
#  1494,
#  209,
#  862,
#  1495,
#  308,
#  109,
#  13,
#  72,
#  57,
#  8,
#  587,
#  3,
#  451,
#  1496,
#  209,
#  862,
#  1497,
#  8,
#  863,
#  864,
#  13,
#  72,
#  57,
#  1498,
#  0,
#  865,
#  4,
#  8,
#  1499,
#  232,
#  232,
#  118,
#  18,
#  126,
#  588,
#  28,
#  1500,
#  1,
#  1501,
#  33,
#  1502,
#  10,
#  8,
#  866,
#  18,
#  126,
#  32,
#  589,
#  50,
#  28,
#  1503,
#  867,
#  10,
#  868,
#  869,
#  1504,
#  4,
#  868,
#  33,
#  1,
#  452,
#  0,
#  1505,
#  4,
#  28,
#  1506,
#  10,
#  1507,
#  4,
#  35,
#  870,
#  1508,
#  1509,
#  1510,
#  1511,
#  1512,
#  1513,
#  1514,
#  4,
#  871,
#  1515,
#  6,
#  1516,
#  872,
#  10,
#  873,
#  126,
#  18,
#  1517,
#  8,
#  1518,
#  364,
#  453,
#  28,
#  1519,
#  365,
#  9,
#  590,
#  3,
#  874,
#  3,
#  1520,
#  1521,
#  8,
#  863,
#  864,
#  25,
#  17,
#  26,
#  42,
#  19,
#  12,
#  51,
#  233,
#  15,
#  366,
#  587,
#  3,
#  451,
#  10,
#  148,
#  2,
#  309,
#  0,
#  875,
#  876,
#  4,
#  1522,
#  16,
#  42,
#  9,
#  367,
#  2,
#  83,
#  1523,
#  4,
#  210,
#  85,
#  30,
#  25,
#  264,
#  3,
#  13,
#  877,
#  38,
#  3,
#  28,
#  591,
#  592,
#  3,
#  40,
#  454,
#  1524,
#  1525,
#  6,
#  11,
#  1526,
#  43,
#  106,
#  77,
#  310,
#  25,
#  1527,
#  89,
#  455,
#  3,
#  77,
#  15,
#  574,
#  67,
#  25,
#  16,
#  5,
#  1528,
#  60,
#  11,
#  1529,
#  15,
#  1530,
#  456,
#  1,
#  60,
#  3,
#  368,
#  7,
#  34,
#  20,
#  16,
#  5,
#  878,
#  6,
#  1531,
#  32,
#  73,
#  1532,
#  1,
#  234,
#  24,
#  235,
#  3,
#  130,
#  0,
#  879,
#  38,
#  880,
#  236,
#  68,
#  9,
#  5,
#  1533,
#  881,
#  26,
#  9,
#  457,
#  76,
#  6,
#  458,
#  27,
#  211,
#  20,
#  6,
#  13,
#  882,
#  1534,
#  15,
#  265,
#  883,
#  0,
#  207,
#  49,
#  25,
#  1535,
#  0,
#  1536,
#  2,
#  58,
#  8,
#  574,
#  459,
#  20,
#  10,
#  8,
#  189,
#  311,
#  15,
#  107,
#  49,
#  10,
#  24,
#  593,
#  1537,
#  2,
#  23,
#  594,
#  15,
#  366,
#  3,
#  1538,
#  98,
#  2,
#  119,
#  12,
#  32,
#  43,
#  235,
#  2,
#  45,
#  149,
#  1539,
#  101,
#  63,
#  17,
#  83,
#  1540,
#  8,
#  595,
#  6,
#  96,
#  5,
#  460,
#  51,
#  3,
#  1541,
#  8,
#  1542,
#  20,
#  2,
#  596,
#  15,
#  366,
#  11,
#  2,
#  83,
#  119,
#  0,
#  884,
#  11,
#  83,
#  597,
#  21,
#  6,
#  13,
#  1543,
#  39,
#  2,
#  1544,
#  3,
#  583,
#  266,
#  264,
#  3,
#  461,
#  0,
#  237,
#  38,
#  3,
#  1545,
#  1546,
#  0,
#  1547,
#  4,
#  462,
#  369,
#  89,
#  115,
#  1548,
#  15,
#  1549,
#  119,
#  4,
#  15,
#  885,
#  1550,
#  131,
#  15,
#  463,
#  598,
#  886,
#  7,
#  464,
#  12,
#  3,
#  15,
#  265,
#  1551,
#  7,
#  78,
#  1552,
#  0,
#  1553,
#  4,
#  5,
#  1554,
#  14,
#  599,
#  3,
#  25,
#  6,
#  1555,
#  1556,
#  1557,
#  3,
#  600,
#  5,
#  887,
#  1558,
#  29,
#  15,
#  370,
#  1559,
#  601,
#  1560,
#  3,
#  0,
#  602,
#  888,
#  231,
#  1561,
#  79,
#  11,
#  227,
#  26,
#  46,
#  889,
#  3,
#  1562,
#  96,
#  603,
#  1563,
#  20,
#  1564,
#  261,
#  9,
#  0,
#  604,
#  1565,
#  74,
#  11,
#  605,
#  845,
#  37,
#  0,
#  606,
#  890,
#  891,
#  1566,
#  1,
#  1567,
#  6,
#  465,
#  1568,
#  26,
#  19,
#  2,
#  1569,
#  26,
#  892,
#  26,
#  267,
#  8,
#  109,
#  150,
#  2,
#  19,
#  464,
#  8,
#  606,
#  1570,
#  100,
#  190,
#  24,
#  1571,
#  238,
#  1572,
#  893,
#  8,
#  607,
#  1573,
#  12,
#  3,
#  110,
#  1574,
#  102,
#  268,
#  3,
#  1575,
#  1,
#  32,
#  0,
#  269,
#  312,
#  185,
#  1576,
#  1577,
#  166,
#  1578,
#  8,
#  33,
#  1,
#  21,
#  14,
#  1579,
#  894,
#  4,
#  1580,
#  84,
#  11,
#  166,
#  264,
#  1581,
#  3,
#  461,
#  14,
#  1582,
#  3,
#  15,
#  265,
#  371,
#  38,
#  191,
#  3,
#  583,
#  148,
#  16,
#  27,
#  895,
#  38,
#  37,
#  1583,
#  1584,
#  3,
#  1585,
#  14,
#  599,
#  1586,
#  1,
#  465,
#  466,
#  1587,
#  54,
#  115,
#  103,
#  118,
#  464,
#  35,
#  1588,
#  1589,
#  3,
#  8,
#  608,
#  1590,
#  7,
#  22,
#  28,
#  265,
#  151,
#  266,
#  65,
#  21,
#  22,
#  896,
#  23,
#  7,
#  451,
#  270,
#  1591,
#  118,
#  467,
#  27,
#  57,
#  8,
#  1592,
#  1,
#  43,
#  9,
#  132,
#  8,
#  33,
#  30,
#  897,
#  270,
#  1,
#  42,
#  9,
#  367,
#  1,
#  29,
#  8,
#  468,
#  4,
#  28,
#  2,
#  23,
#  1593,
#  190,
#  266,
#  118,
#  2,
#  1594,
#  8,
#  109,
#  16,
#  131,
#  1595,
#  16,
#  898,
#  16,
#  131,
#  1596,
#  8,
#  33,
#  9,
#  52,
#  74,
#  1597,
#  8,
#  1598,
#  133,
#  609,
#  16,
#  1599,
#  1600,
#  886,
#  12,
#  10,
#  1601,
#  16,
#  1602,
#  1,
#  365,
#  9,
#  52,
#  74,
#  29,
#  82,
#  1603,
#  78,
#  1604,
#  2,
#  45,
#  1605,
#  4,
#  899,
#  372,
#  141,
#  67,
#  12,
#  2,
#  69,
#  1606,
#  8,
#  1607,
#  148,
#  90,
#  1608,
#  17,
#  3,
#  24,
#  469,
#  149,
#  33,
#  3,
#  900,
#  1609,
#  373,
#  1,
#  855,
#  28,
#  1610,
#  1,
#  374,
#  54,
#  1611,
#  901,
#  1612,
#  901,
#  1613,
#  6,
#  1614,
#  84,
#  13,
#  902,
#  1,
#  1615,
#  470,
#  2,
#  49,
#  903,
#  11,
#  2,
#  22,
#  239,
#  26,
#  1616,
#  1,
#  10,
#  68,
#  471,
#  3,
#  22,
#  1617,
#  1618,
#  184,
#  212,
#  1619,
#  4,
#  1620,
#  8,
#  904,
#  61,
#  472,
#  1621,
#  148,
#  104,
#  1,
#  104,
#  1622,
#  7,
#  30,
#  134,
#  10,
#  98,
#  2,
#  22,
#  62,
#  1623,
#  1624,
#  14,
#  7,
#  1625,
#  14,
#  77,
#  89,
#  115,
#  99,
#  7,
#  ...]

# %%
# 4. Create input sequences and targets
sequence_length = 20  # Örnek dizi uzunluğu, bunu artırıp azaltarak deneyebilirsiniz.
sequences = []

for i in range(len(indexed_words) - sequence_length):
    seq_in = indexed_words[i:i + sequence_length]
    seq_out = indexed_words[i + sequence_length]
    sequences.append((seq_in, seq_out))

# %%
sequences
# Out:
# [([5,
#    1427,
#    440,
#    258,
#    32,
#    1428,
#    839,
#    1429,
#    32,
#    1430,
#    1431,
#    1432,
#    1,
#    1433,
#    1434,
#    10,
#    1435,
#    1436,
#    1,
#    1437],
#   1438),
#  ([1427,
#    440,
#    258,
#    32,
#    1428,
#    839,
#    1429,
#    32,
#    1430,
#    1431,
#    1432,
#    1,
#    1433,
#    1434,
#    10,
#    1435,
#    1436,
#    1,
#    1437,
#    1438],
#   1439),
#  ([440,
#    258,
#    32,
#    1428,
#    839,
#    1429,
#    32,
#    1430,
#    1431,
#    1432,
#    1,
#    1433,
#    1434,
#    10,
#    1435,
#    1436,
#    1,
#    1437,
#    1438,
#    1439],
#   839),
#  ([258,
#    32,
#    1428,
#    839,
#    1429,
#    32,
#    1430,
#    1431,
#    1432,
#    1,
#    1433,
#    1434,
#    10,
#    1435,
#    1436,
#    1,
#    1437,
#    1438,
#    1439,
#    839],
#   1440),
#  ([32,
#    1428,
#    839,
#    1429,
#    32,
#    1430,
#    1431,
#    1432,
#    1,
#    1433,
#    1434,
#    10,
#    1435,
#    1436,
#    1,
#    1437,
#    1438,
#    1439,
#    839,
#    1440],
#   840),
#  ([1428,
#    839,
#    1429,
#    32,
#    1430,
#    1431,
#    1432,
#    1,
#    1433,
#    1434,
#    1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5],
#   1458),
#  ([1454,
#    443,
#    1455,
#    182,
#    259,
#    1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458],
#   38),
#  ([443,
#    1455,
#    182,
#    259,
#    1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38],
#   1459),
#  ([1455,
#    182,
#    259,
#    1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459],
#   6),
#  ([182,
#    259,
#    1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6],
#   1460),
#  ([259,
#    1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460],
#   576),
#  ([1456,
#    260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576],
#   5),
#  ([260,
#    360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5],
#   1461),
#  ([360,
#    4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461],
#   6),
#  ([4,
#    0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6],
#   0),
#  ([0,
#    302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0],
#   576),
#  ([302,
#    228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576],
#   4),
#  ([228,
#    205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4],
#   164),
#  ([205,
#    4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164],
#   302),
#  ([4,
#    0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302],
#   1462),
#  ([0,
#    302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462],
#   84),
#  ([302,
#    182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84],
#   1463),
#  ([182,
#    1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463],
#   361),
#  ([1457,
#    5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361],
#   303),
#  ([5,
#    1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303],
#   444),
#  ([1458,
#    38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444],
#   304),
#  ([38,
#    1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304],
#   842),
#  ([1459,
#    6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842],
#   1),
#  ([6,
#    1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1],
#   1464),
#  ([1460,
#    576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464],
#   37),
#  ([576,
#    5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37],
#   76),
#  ([5,
#    1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76],
#   1),
#  ([1461,
#    6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1],
#   183),
#  ([6,
#    0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183],
#   207),
#  ([0,
#    576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207],
#   302),
#  ([576,
#    4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302],
#   6),
#  ([4,
#    164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6],
#   0),
#  ([164,
#    302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0],
#   1465),
#  ([302,
#    1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465],
#   4),
#  ([1462,
#    84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4],
#   164),
#  ([84,
#    1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164],
#   1),
#  ([1463,
#    361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1],
#   229),
#  ([361,
#    303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229],
#   156),
#  ([303,
#    444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156],
#   89),
#  ([444,
#    304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89],
#   301),
#  ([304,
#    842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301],
#   40),
#  ([842,
#    1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40],
#   445),
#  ([1,
#    1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445],
#   843),
#  ([1464,
#    37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843],
#   577),
#  ([37,
#    76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577],
#   37),
#  ([76,
#    1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37],
#   1466),
#  ([1,
#    183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466],
#   300),
#  ([183,
#    207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300],
#   261),
#  ([207,
#    302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261],
#   578),
#  ([302,
#    6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578],
#   230),
#  ([6,
#    0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230],
#   6),
#  ([0,
#    1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6],
#   262),
#  ([1465,
#    4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262],
#   231),
#  ([4,
#    164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231],
#   184),
#  ([164,
#    1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184],
#   105),
#  ([1,
#    229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105],
#   362),
#  ([229,
#    156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362],
#   63),
#  ([156,
#    89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63],
#   579),
#  ([89,
#    301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579],
#   13),
#  ([301,
#    40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13],
#   305),
#  ([40,
#    445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305],
#   185),
#  ([445,
#    843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185],
#   1467),
#  ([843,
#    577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467],
#   42),
#  ([577,
#    37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42],
#   1468),
#  ([37,
#    1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468],
#   8),
#  ([1466,
#    300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8],
#   1469),
#  ([300,
#    261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469],
#   93),
#  ([261,
#    578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93],
#   3),
#  ([578,
#    230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3],
#   5),
#  ([230,
#    6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5],
#   1470),
#  ([6,
#    262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470],
#   38),
#  ([262,
#    231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38],
#   5),
#  ([231,
#    184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5],
#   844),
#  ([184,
#    105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844],
#   208),
#  ([105,
#    362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208],
#   845),
#  ([362,
#    63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845],
#   114),
#  ([63,
#    579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114],
#   5),
#  ([579,
#    13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5],
#   363),
#  ([13,
#    305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363],
#   446),
#  ([305,
#    185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446],
#   1471),
#  ([185,
#    1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471],
#   300),
#  ([1467,
#    42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300],
#   578),
#  ([42,
#    1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578],
#   19),
#  ([1468,
#    8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19],
#   846),
#  ([8,
#    1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846],
#   847),
#  ([1469,
#    93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847],
#   447),
#  ([93,
#    3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447],
#   6),
#  ([3,
#    5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6],
#   848),
#  ([5,
#    1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848],
#   300),
#  ([1470,
#    38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300],
#   1472),
#  ([38,
#    5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472],
#   19),
#  ([5,
#    844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19],
#   846),
#  ([844,
#    208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19,
#    846],
#   258),
#  ([208,
#    845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19,
#    846,
#    258],
#   165),
#  ([845,
#    114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19,
#    846,
#    258,
#    165],
#   0),
#  ([114,
#    5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19,
#    846,
#    258,
#    165,
#    0],
#   1473),
#  ([5,
#    363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19,
#    846,
#    258,
#    165,
#    0,
#    1473],
#   1),
#  ([363,
#    446,
#    1471,
#    300,
#    578,
#    19,
#    846,
#    847,
#    447,
#    6,
#    848,
#    300,
#    1472,
#    19,
#    846,
#    258,
#    165,
#    0,
#    1473,
#    1],
#   69),
#  ([446,
#    1471,
#    1,
#    69,
#    0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97],
#   4),
#  ([165,
#    0,
#    1473,
#    1,
#    69,
#    0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4],
#   40),
#  ([0,
#    1473,
#    1,
#    69,
#    0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40],
#   1475),
#  ([1473,
#    1,
#    69,
#    0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475],
#   76),
#  ([1,
#    69,
#    0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76],
#   187),
#  ([69,
#    0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187],
#   357),
#  ([0,
#    186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357],
#   448),
#  ([186,
#    93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448],
#   100),
#  ([93,
#    3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448,
#    100],
#   0),
#  ([3,
#    5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448,
#    100,
#    0],
#   157),
#  ([5,
#    849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448,
#    100,
#    0,
#    157],
#   580),
#  ([849,
#    850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448,
#    100,
#    0,
#    157,
#    580],
#   3),
#  ([850,
#    1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448,
#    100,
#    0,
#    157,
#    580,
#    3],
#   1476),
#  ([1474,
#    6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    40,
#    1475,
#    76,
#    187,
#    357,
#    448,
#    100,
#    0,
#    157,
#    580,
#    3,
#    1476],
#   853),
#  ([6,
#    851,
#    30,
#    852,
#    0,
#    97,
#    4,
#    583,
#    55,
#    6,
#    262],
#   856),
#  ([854,
#    55,
#    10,
#    8,
#    582,
#    1,
#    855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856],
#   10),
#  ([55,
#    10,
#    8,
#    582,
#    1,
#    855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10],
#   1486),
#  ([10,
#    8,
#    582,
#    1,
#    855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486],
#   10),
#  ([8,
#    582,
#    1,
#    855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10],
#   1487),
#  ([582,
#    1,
#    855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487],
#   1),
#  ([1,
#    855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1],
#   10),
#  ([855,
#    35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10],
#   1488),
#  ([35,
#    33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488],
#   188),
#  ([33,
#    1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188],
#   857),
#  ([1484,
#    55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857],
#   1),
#  ([55,
#    1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1],
#   24),
#  ([1485,
#    20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24],
#   584),
#  ([20,
#    2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584],
#   115),
#  ([2,
#    19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115],
#   1),
#  ([19,
#    583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1],
#   88),
#  ([583,
#    55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88],
#   1),
#  ([55,
#    6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1],
#   1489),
#  ([6,
#    262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489],
#   261),
#  ([262,
#    856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261],
#   25),
#  ([856,
#    10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25],
#   356),
#  ([10,
#    1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356],
#   40),
#  ([1486,
#    10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40],
#   1490),
#  ([10,
#    1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490],
#   1491),
#  ([1487,
#    1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491],
#   585),
#  ([1,
#    10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585],
#   56),
#  ([10,
#    1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56],
#   858),
#  ([1488,
#    188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858],
#   586),
#  ([188,
#    857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586],
#   0),
#  ([857,
#    1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0],
#   1492),
#  ([1,
#    24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492],
#   10),
#  ([24,
#    584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10],
#   859),
#  ([584,
#    115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859],
#   263),
#  ([115,
#    1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263],
#   4),
#  ([1,
#    88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4],
#   860),
#  ([88,
#    1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860],
#   64),
#  ([1,
#    1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64],
#   140),
#  ([1489,
#    261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140],
#   10),
#  ([261,
#    25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10],
#   1493),
#  ([25,
#    356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493],
#   307),
#  ([356,
#    40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307],
#   8),
#  ([40,
#    1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8],
#   861),
#  ([1490,
#    1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861],
#   8),
#  ([1491,
#    585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8],
#   584),
#  ([585,
#    56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584],
#   1494),
#  ([56,
#    858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494],
#   209),
#  ([858,
#    586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209],
#   862),
#  ([586,
#    0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862],
#   1495),
#  ([0,
#    1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495],
#   308),
#  ([1492,
#    10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308],
#   109),
#  ([10,
#    859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109],
#   13),
#  ([859,
#    263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13],
#   72),
#  ([263,
#    4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13,
#    72],
#   57),
#  ([4,
#    860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13,
#    72,
#    57],
#   8),
#  ([860,
#    64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13,
#    72,
#    57,
#    8],
#   587),
#  ([64,
#    140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13,
#    72,
#    57,
#    8,
#    587],
#   3),
#  ([140,
#    10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13,
#    72,
#    57,
#    8,
#    587,
#    3],
#   451),
#  ([10,
#    1493,
#    307,
#    8,
#    861,
#    8,
#    584,
#    1494,
#    209,
#    862,
#    1495,
#    308,
#    109,
#    13,
#    72,
#    57,
#    8,
#    587,
#    3,
#    451],
# ...
#    1604,
#    2,
#    45,
#    1605,
#    4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608],
#   17),
#  ([78,
#    1604,
#    2,
#    45,
#    1605,
#    4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17],
#   3),
#  ([1604,
#    2,
#    45,
#    1605,
#    4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3],
#   24),
#  ([2,
#    45,
#    1605,
#    4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24],
#   469),
#  ([45,
#    1605,
#    4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469],
#   149),
#  ([1605,
#    4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149],
#   33),
#  ([4,
#    899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149,
#    33],
#   3),
#  ([899,
#    372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149,
#    33,
#    3],
#   900),
#  ([372,
#    141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149,
#    33,
#    3,
#    900],
#   1609),
#  ([141,
#    67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149,
#    33,
#    3,
#    900,
#    1609],
#   373),
#  ([67,
#    12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149,
#    33,
#    3,
#    900,
#    1609,
#    373],
#   1),
#  ([12,
#    2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    469,
#    149,
#    33,
#    3,
#    900,
#    1609,
#    373,
#    1],
#   855),
#  ([2,
#    69,
#    1606,
#    8,
#    1607,
#    148,
#    90,
#    1608,
#    17,
#    3,
#    24,
#    3,
#    905,
#    15,
#    1627,
#    3,
#    15,
#    265,
#    371,
#    38,
#    191,
#    0,
#    454],
#   4),
#  ([77,
#    89,
#    115,
#    99,
#    7,
#    1626,
#    610,
#    3,
#    905,
#    15,
#    1627,
#    3,
#    15,
#    265,
#    371,
#    38,
#    191,
#    0,
#    454,
#    4],
#   129),
#  ([89,
#    115,
#    99,
#    7,
#    1626,
#    610,
#    3,
#    905,
#    15,
#    1627,
#    3,
#    15,
#    265,
#    371,
#    38,
#    191,
#    0,
#    454,
#    4,
#    129],
#   1628),
#  ([115,
#    99,
#    7,
#    1626,
#    610,
#    3,
#    905,
#    15,
#    1627,
#    3,
#    15,
#    265,
#    371,
#    38,
#    191,
#    0,
#    454,
#    4,
#    129,
#    1628],
#   7),
#  ([99,
#    7,
#    1626,
#    610,
#    3,
#    905,
#    15,
#    1627,
#    3,
#    15,
#    265,
#    371,
#    38,
#    191,
#    0,
#    454,
#    4,
#    129,
#    1628,
#    7],
#   100),
#  ([7,
#    1626,
#    610,
#    3,
#    905,
#    15,
#    1627,
#    3,
#    15,
#    265,
#    371,
#    38,
#    191,
#    0,
#    454,
#    4,
#    129,
#    1628,
#    7,
#    100],
#   365),
#  ...]

# %%
print(f"Created a total of {len(sequences)} sequences.")
# Out:
# Created a total of 16653 sequences.

# %%
import torch.nn.functional as F
# Define the model
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers=1, dropout=0.3):
        super(LSTMModel, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        # Use pre-trained embeddings or larger embedding dimension
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        
        # Use Bidirectional LSTM
        self.lstm = nn.LSTM(embedding_dim, 
                           hidden_dim,
                           num_layers=num_layers,
                           dropout=dropout if num_layers > 1 else 0,
                           batch_first=True,
                           bidirectional=True)  # Added bidirectional
        
        # Add Layer Normalization
        self.layer_norm = nn.LayerNorm(hidden_dim * 2)  # x2 for bidirectional
        
        self.dropout = nn.Dropout(dropout)
        
        # Deeper FC layers
        self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, vocab_size)
        
    def forward(self, x, hidden=None):
        batch_size = x.size(0)
        
        if hidden is None:
            h0 = torch.zeros(self.num_layers * 2, batch_size, self.hidden_dim).to(x.device)  # x2 for bidirectional
            c0 = torch.zeros(self.num_layers * 2, batch_size, self.hidden_dim).to(x.device)
            hidden = (h0, c0)
        
        embeds = self.embedding(x)
        lstm_out, hidden = self.lstm(embeds, hidden)
        
        # Get the last time step
        lstm_out = lstm_out[:, -1, :]
        
        # Apply layer normalization
        lstm_out = self.layer_norm(lstm_out)
        lstm_out = self.dropout(lstm_out)
        
        # Use two FC layers
        output = F.relu(self.fc1(lstm_out))
        output = self.dropout(output)
        output = self.fc2(output)
        
        return output, hidden

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import itertools
import time

# --- TRAINING FUNCTION FOR GRID SEARCH ---

# Split the sequences data into (input_sequence, target_word)
inputs = torch.tensor([item[0] for item in sequences])
targets = torch.tensor([item[1] for item in sequences])

def train_for_grid_search(params):
    """
    Trains the model with the given hyperparameters and returns the final loss.
    """
    print(f"--- Trying parameters: {params} ---")
    
    # Create model, DataLoader, Criterion and Optimizer with parameters
    model = LSTMModel(
        vocab_size=vocab_size,
        embedding_dim=params['embedding_dim'],
        hidden_dim=params['hidden_dim'],
        num_layers=params['num_layers'],
        dropout=params['dropout']
    ).to(device)
    
    dataset = TensorDataset(inputs, targets)
    data_loader = DataLoader(dataset, shuffle=True, batch_size=params['batch_size'])
    
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=params['learning_rate'])
    
    # Using fewer epochs for grid search to save time
    num_epochs = 5
    model.train()
    
    start_time = time.time()
    for epoch in range(num_epochs):
        epoch_loss = 0
        for inputs_batch, targets_batch in data_loader:
            inputs_batch, targets_batch = inputs_batch.to(device), targets_batch.to(device)
            
            optimizer.zero_grad()
            outputs, hidden = model(inputs_batch)
            loss = criterion(outputs, targets_batch)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
        
        avg_loss = epoch_loss / len(data_loader)
        print(f"  Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")

    end_time = time.time()
    print(f"  Completed in: {end_time - start_time:.2f} seconds")
    
    # Return the average loss of the last epoch
    return avg_loss

# %%
# --- GRID SEARCH SETUP ---

# 1. The larger this list, the longer the process will take!
param_grid = {
    'embedding_dim': [256, 300, 400],  # Larger embeddings
    'hidden_dim': [256, 384, 512],     # Larger hidden layers
    'learning_rate': [0.0001, 0.0005, 0.001, 0.005],  # More LR options
    'batch_size': [32],      
    'num_layers': [2],
    'dropout': [0.2]
}

# 2. Create all possible parameter combinations
keys, values = zip(*param_grid.items())
param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]

results = []
best_loss = float('inf')
best_params = None

print(f"Starting Grid Search. Trying {len(param_combinations)} combinations in total.")

# 3. Train the model for each combination
for params in param_combinations:
    loss = train_for_grid_search(params)
    results.append({'params': params, 'loss': loss})
    
    if loss < best_loss:
        best_loss = loss
        best_params = params

# 4. Print the best result
print("\n--- Grid Search Complete ---")
print(f"Lowest Loss: {best_loss:.4f}")
print(f"Best Hyperparameters: {best_params}")
# Out:
# Starting Grid Search. Trying 36 combinations in total.
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 256, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2548
#   Epoch 2/5, Loss: 6.5273
#   Epoch 3/5, Loss: 6.1839
#   Epoch 4/5, Loss: 5.8840
#   Epoch 5/5, Loss: 5.6163
#   Completed in: 39.91 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 256, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0262
#   Epoch 2/5, Loss: 6.3857
#   Epoch 3/5, Loss: 5.8915
#   Epoch 4/5, Loss: 5.4145
#   Epoch 5/5, Loss: 4.9584
#   Completed in: 39.77 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 256, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0627
#   Epoch 2/5, Loss: 6.6800
#   Epoch 3/5, Loss: 6.3962
#   Epoch 4/5, Loss: 6.0561
#   Epoch 5/5, Loss: 5.7047
#   Completed in: 39.90 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 256, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2461
#   Epoch 2/5, Loss: 6.8656
#   Epoch 3/5, Loss: 6.6933
#   Epoch 4/5, Loss: 6.5973
#   Epoch 5/5, Loss: 6.5191
#   Completed in: 39.84 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 384, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.1415
#   Epoch 2/5, Loss: 6.3660
#   Epoch 3/5, Loss: 5.9322
#   Epoch 4/5, Loss: 5.5682
#   Epoch 5/5, Loss: 5.2386
#   Completed in: 69.07 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 384, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0148
#   Epoch 2/5, Loss: 6.4660
#   Epoch 3/5, Loss: 5.9812
#   Epoch 4/5, Loss: 5.4920
#   Epoch 5/5, Loss: 5.0295
#   Completed in: 69.02 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 384, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0695
#   Epoch 2/5, Loss: 6.7135
#   Epoch 3/5, Loss: 6.4428
#   Epoch 4/5, Loss: 6.1163
#   Epoch 5/5, Loss: 5.7846
#   Completed in: 69.15 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 384, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.3092
#   Epoch 2/5, Loss: 6.9411
#   Epoch 3/5, Loss: 6.7610
#   Epoch 4/5, Loss: 6.6407
#   Epoch 5/5, Loss: 6.5747
#   Completed in: 69.16 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 512, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0874
#   Epoch 2/5, Loss: 6.2581
#   Epoch 3/5, Loss: 5.7941
#   Epoch 4/5, Loss: 5.3831
#   Epoch 5/5, Loss: 4.9834
#   Completed in: 104.58 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 512, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0257
#   Epoch 2/5, Loss: 6.5629
#   Epoch 3/5, Loss: 6.1902
#   Epoch 4/5, Loss: 5.7898
#   Epoch 5/5, Loss: 5.3834
#   Completed in: 104.64 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 512, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0712
#   Epoch 2/5, Loss: 6.7538
#   Epoch 3/5, Loss: 6.4994
#   Epoch 4/5, Loss: 6.2170
#   Epoch 5/5, Loss: 5.9065
#   Completed in: 104.64 seconds
# --- Trying parameters: {'embedding_dim': 256, 'hidden_dim': 512, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.3841
#   Epoch 2/5, Loss: 6.9934
#   Epoch 3/5, Loss: 6.8339
#   Epoch 4/5, Loss: 6.7381
#   Epoch 5/5, Loss: 6.6559
#   Completed in: 104.70 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 256, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2803
#   Epoch 2/5, Loss: 6.4904
#   Epoch 3/5, Loss: 6.1220
#   Epoch 4/5, Loss: 5.8072
#   Epoch 5/5, Loss: 5.5330
#   Completed in: 41.25 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 256, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0227
#   Epoch 2/5, Loss: 6.4068
#   Epoch 3/5, Loss: 5.9006
#   Epoch 4/5, Loss: 5.4020
#   Epoch 5/5, Loss: 4.9272
#   Completed in: 41.25 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 256, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0597
#   Epoch 2/5, Loss: 6.6562
#   Epoch 3/5, Loss: 6.3170
#   Epoch 4/5, Loss: 5.9280
#   Epoch 5/5, Loss: 5.5403
#   Completed in: 41.14 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 256, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2470
#   Epoch 2/5, Loss: 6.9175
#   Epoch 3/5, Loss: 6.7474
#   Epoch 4/5, Loss: 6.6450
#   Epoch 5/5, Loss: 6.5745
#   Completed in: 41.14 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 384, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.1443
#   Epoch 2/5, Loss: 6.3362
#   Epoch 3/5, Loss: 5.8954
#   Epoch 4/5, Loss: 5.5139
#   Epoch 5/5, Loss: 5.1620
#   Completed in: 70.88 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 384, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0127
#   Epoch 2/5, Loss: 6.4636
#   Epoch 3/5, Loss: 5.9954
#   Epoch 4/5, Loss: 5.4954
#   Epoch 5/5, Loss: 5.0253
#   Completed in: 70.89 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 384, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0620
#   Epoch 2/5, Loss: 6.6612
#   Epoch 3/5, Loss: 6.3550
#   Epoch 4/5, Loss: 6.0326
#   Epoch 5/5, Loss: 5.6771
#   Completed in: 71.02 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 384, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2887
#   Epoch 2/5, Loss: 6.9064
#   Epoch 3/5, Loss: 6.7357
#   Epoch 4/5, Loss: 6.6176
#   Epoch 5/5, Loss: 6.5564
#   Completed in: 70.96 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 512, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0801
#   Epoch 2/5, Loss: 6.2203
#   Epoch 3/5, Loss: 5.7388
#   Epoch 4/5, Loss: 5.3151
#   Epoch 5/5, Loss: 4.9003
#   Completed in: 106.60 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 512, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0175
#   Epoch 2/5, Loss: 6.5657
#   Epoch 3/5, Loss: 6.1705
#   Epoch 4/5, Loss: 5.7357
#   Epoch 5/5, Loss: 5.3031
#   Completed in: 106.86 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 512, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0711
#   Epoch 2/5, Loss: 6.7573
#   Epoch 3/5, Loss: 6.5468
#   Epoch 4/5, Loss: 6.2510
#   Epoch 5/5, Loss: 5.9256
#   Completed in: 106.86 seconds
# --- Trying parameters: {'embedding_dim': 300, 'hidden_dim': 512, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.3288
#   Epoch 2/5, Loss: 7.0229
#   Epoch 3/5, Loss: 6.8582
#   Epoch 4/5, Loss: 6.7394
#   Epoch 5/5, Loss: 6.6605
#   Completed in: 106.88 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 256, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2641
#   Epoch 2/5, Loss: 6.4807
#   Epoch 3/5, Loss: 6.1032
#   Epoch 4/5, Loss: 5.7736
#   Epoch 5/5, Loss: 5.4803
#   Completed in: 43.80 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 256, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0106
#   Epoch 2/5, Loss: 6.3085
#   Epoch 3/5, Loss: 5.7647
#   Epoch 4/5, Loss: 5.2467
#   Epoch 5/5, Loss: 4.7412
#   Completed in: 43.83 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 256, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0427
#   Epoch 2/5, Loss: 6.6030
#   Epoch 3/5, Loss: 6.2358
#   Epoch 4/5, Loss: 5.8242
#   Epoch 5/5, Loss: 5.4247
#   Completed in: 43.59 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 256, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2576
#   Epoch 2/5, Loss: 6.8771
#   Epoch 3/5, Loss: 6.7022
#   Epoch 4/5, Loss: 6.5966
#   Epoch 5/5, Loss: 6.5212
#   Completed in: 43.57 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 384, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.1412
#   Epoch 2/5, Loss: 6.2964
#   Epoch 3/5, Loss: 5.8460
#   Epoch 4/5, Loss: 5.4508
#   Epoch 5/5, Loss: 5.0767
#   Completed in: 74.28 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 384, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0146
#   Epoch 2/5, Loss: 6.4379
#   Epoch 3/5, Loss: 5.9180
#   Epoch 4/5, Loss: 5.3882
#   Epoch 5/5, Loss: 4.8650
#   Completed in: 74.47 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 384, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0601
#   Epoch 2/5, Loss: 6.6997
#   Epoch 3/5, Loss: 6.3903
#   Epoch 4/5, Loss: 6.0478
#   Epoch 5/5, Loss: 5.6964
#   Completed in: 74.73 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 384, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.2952
#   Epoch 2/5, Loss: 6.9065
#   Epoch 3/5, Loss: 6.7450
#   Epoch 4/5, Loss: 6.6516
#   Epoch 5/5, Loss: 6.5695
#   Completed in: 74.75 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 512, 'learning_rate': 0.0001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0727
#   Epoch 2/5, Loss: 6.1954
#   Epoch 3/5, Loss: 5.6945
#   Epoch 4/5, Loss: 5.2521
#   Epoch 5/5, Loss: 4.8060
#   Completed in: 110.79 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 512, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0060
#   Epoch 2/5, Loss: 6.5143
#   Epoch 3/5, Loss: 6.0512
#   Epoch 4/5, Loss: 5.5840
#   Epoch 5/5, Loss: 5.0884
#   Completed in: 110.78 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 512, 'learning_rate': 0.001, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.0579
#   Epoch 2/5, Loss: 6.7868
#   Epoch 3/5, Loss: 6.5618
#   Epoch 4/5, Loss: 6.2972
#   Epoch 5/5, Loss: 5.9937
#   Completed in: 110.91 seconds
# --- Trying parameters: {'embedding_dim': 400, 'hidden_dim': 512, 'learning_rate': 0.005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2} ---
#   Epoch 1/5, Loss: 7.3275
#   Epoch 2/5, Loss: 6.9352
#   Epoch 3/5, Loss: 6.7967
#   Epoch 4/5, Loss: 6.6706
#   Epoch 5/5, Loss: 6.6108
#   Completed in: 110.82 seconds
#
# --- Grid Search Complete ---
# Lowest Loss: 4.7412
# Best Hyperparameters: {'embedding_dim': 400, 'hidden_dim': 256, 'learning_rate': 0.0005, 'batch_size': 32, 'num_layers': 2, 'dropout': 0.2}

# %%
# --- FINAL MODEL TRAINING ---

# 1. Create the final model with the best parameters
final_model = LSTMModel(
    vocab_size=vocab_size,
    embedding_dim=best_params['embedding_dim'],
    hidden_dim=best_params['hidden_dim'],
    num_layers=best_params['num_layers'],
    dropout=best_params['dropout']
).to(device)

# 2. Create DataLoader
dataset = TensorDataset(inputs, targets)
data_loader = DataLoader(dataset, shuffle=True, batch_size=best_params['batch_size'])

# 3. Define Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(final_model.parameters(), lr=best_params['learning_rate'])

# 4. Run the final training loop for more epochs
num_epochs = 40
final_model.train()

print("Starting final training with the best hyperparameters...")
for epoch in range(num_epochs):
    epoch_loss = 0
    for inputs_batch, targets_batch in data_loader:
        inputs_batch, targets_batch = inputs_batch.to(device), targets_batch.to(device)
        optimizer.zero_grad()
        outputs, hidden = final_model(inputs_batch)  # FIX: Removed duplicate variable name
        loss = criterion(outputs, targets_batch)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

    avg_loss = epoch_loss / len(data_loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")

print("Final training complete.")
# Out:
# Starting final training with the best hyperparameters...
# Epoch 1/40, Loss: 7.0097
# Epoch 2/40, Loss: 6.3231
# Epoch 3/40, Loss: 5.7846
# Epoch 4/40, Loss: 5.2605
# Epoch 5/40, Loss: 4.7544
# Epoch 6/40, Loss: 4.2271
# Epoch 7/40, Loss: 3.7221
# Epoch 8/40, Loss: 3.2386
# Epoch 9/40, Loss: 2.7589
# Epoch 10/40, Loss: 2.3693
# Epoch 11/40, Loss: 1.9847
# Epoch 12/40, Loss: 1.6689
# Epoch 13/40, Loss: 1.4222
# Epoch 14/40, Loss: 1.2106
# Epoch 15/40, Loss: 1.0298
# Epoch 16/40, Loss: 0.9192
# Epoch 17/40, Loss: 0.7872
# Epoch 18/40, Loss: 0.7091
# Epoch 19/40, Loss: 0.6113
# Epoch 20/40, Loss: 0.5619
# Epoch 21/40, Loss: 0.5121
# Epoch 22/40, Loss: 0.4705
# Epoch 23/40, Loss: 0.4277
# Epoch 24/40, Loss: 0.4154
# Epoch 25/40, Loss: 0.3892
# Epoch 26/40, Loss: 0.3437
# Epoch 27/40, Loss: 0.3308
# Epoch 28/40, Loss: 0.3249
# Epoch 29/40, Loss: 0.3116
# Epoch 30/40, Loss: 0.3127
# Epoch 31/40, Loss: 0.2823
# Epoch 32/40, Loss: 0.2795
# Epoch 33/40, Loss: 0.2588
# Epoch 34/40, Loss: 0.2543
# Epoch 35/40, Loss: 0.2581
# Epoch 36/40, Loss: 0.2483
# Epoch 37/40, Loss: 0.2520
# Epoch 38/40, Loss: 0.2347
# Epoch 39/40, Loss: 0.2200
# Epoch 40/40, Loss: 0.2232
# Final training complete.

# %%
def generate_text(model, start_text, num_words=50, temperature=0.8):
    """
    Generates text using the trained model.
    
    Args:
        model: The trained LSTM model
        start_text: Initial text to start generation (must be at least sequence_length words)
        num_words: Number of words to generate
        temperature: Controls randomness (0.1=conservative, 1.0=normal, 2.0=creative)
    """
    model.eval() # Set the model to evaluation mode

    # Process the starting text
    words = start_text.lower().split()
    
    # Make sure we have enough words for a full sequence
    if len(words) < sequence_length:
        print(f"Warning: Start text must have at least {sequence_length} words. Padding with 'the'.")
        words = ['the'] * (sequence_length - len(words)) + words
    
    # Take only the last sequence_length words if we have too many
    words = words[-sequence_length:]
    
    # Convert words to indices (use 0 for unknown words)
    current_sequence = [word_to_idx.get(w, 0) for w in words]
    generated_words = words.copy()
    
    with torch.no_grad(): # We don't need to calculate gradients for generation
        for _ in range(num_words):
            # Convert current sequence to tensor
            input_tensor = torch.tensor([current_sequence], device=device)
            
            # Get the model's output
            output, _ = model(input_tensor)
            
            # Apply temperature to the output logits
            word_weights = output.squeeze().div(temperature).exp().cpu()
            
            # Sample the next word index from the probability distribution
            word_idx = torch.multinomial(word_weights, 1)[0].item()
            
            # Update the sequence: remove first word, add new word
            current_sequence = current_sequence[1:] + [word_idx]
            
            # Convert the index back to a word and add to our list
            generated_word = idx_to_word[word_idx]
            generated_words.append(generated_word)

    return ' '.join(generated_words)

# %%
# Test the text generation
start_prompt = "shall i compare thee to a summers day thou art more lovely and temperate rough winds do shake the"
generated_text = generate_text(final_model, start_prompt, num_words=30, temperature=0.8)
print("\nGenerated text:")
print(generated_text)
# Out:
# Warning: Start text must have at least 20 words. Padding with 'the'.
#
# Generated text:
# the shall i compare thee to a summers day thou art more lovely and temperate rough winds do shake the head of this athenian swain, that he, awaking when the other do, may all to athens back again repair and think no more of this night's accidents but as the
